# %%
import pandas as pd
import json
import requests

# %%
import requests

url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=1&sort_by=popularity.desc"

headers = {
    "accept": "application/json",
    "Authorization": f"Bearer {api_key}"
}

movies = requests.get(url, headers=headers)

# %%
import requests

url = "https://api.themoviedb.org/3/genre/movie/list?language=en"

headers = {
    "accept": "application/json",
    "Authorization": f"Bearer {api_key}"
}

genres  = requests.get(url, headers=headers)

# %%
movies = movies.json()
genres = genres.json()

# %%
movies = pd.json_normalize(data=movies, record_path='results')
movies.head(3)
# Out:
#    adult                     backdrop_path      genre_ids       id  \
# 0  False  /r9oTasGQofvkQY5vlUXglneF64Z.jpg       [28, 35]  1029575
# 1  False  /5a4JdoFwll5DRtKMe7JLuGQ9yJm.jpg  [18, 878, 28]   695721
# 2  False  /sRLC052ieEzkQs9dEtPMfFxYkej.jpg          [878]   848326
#
#   original_language                                     original_title  \
# 0                en                                    The Family Plan
# 1                en  The Hunger Games: The Ballad of Songbirds & Sn...
# 2                en             Rebel Moon - Part One: A Child of Fire
#
#                                             overview  popularity  \
# 0  Dan Morgan is many things: a devoted husband, ...    4320.505
# 1  64 years before he becomes the tyrannical pres...    2823.104
# 2  When a peaceful colony on the edge of the gala...    2761.277
#
#                         poster_path release_date  \
# 0  /a6syn9qcU4a54Lmi3JoIr1XvhFU.jpg   2023-12-14
# ...

# %%
genres = pd.json_normalize(data=genres['genres'])
genres
# Out:
#        id             name
# 0      28           Action
# 1      12        Adventure
# 2      16        Animation
# 3      35           Comedy
# 4      80            Crime
# 5      99      Documentary
# 6      18            Drama
# 7   10751           Family
# 8      14          Fantasy
# 9      36          History
# 10     27           Horror
# 11  10402            Music
# 12   9648          Mystery
# 13  10749          Romance
# 14    878  Science Fiction
# 15  10770         TV Movie
# 16     53         Thriller
# 17  10752              War
# 18     37          Western

# %%
id_name_dict = genres.set_index('id')['name'].to_dict()
id_name_dict
# Out:
# {28: 'Action',
#  12: 'Adventure',
#  16: 'Animation',
#  35: 'Comedy',
#  80: 'Crime',
#  99: 'Documentary',
#  18: 'Drama',
#  10751: 'Family',
#  14: 'Fantasy',
#  36: 'History',
#  27: 'Horror',
#  10402: 'Music',
#  9648: 'Mystery',
#  10749: 'Romance',
#  878: 'Science Fiction',
#  10770: 'TV Movie',
#  53: 'Thriller',
#  10752: 'War',
#  37: 'Western'}

# %%
movies['genre_ids'] = movies['genre_ids'].apply(lambda genre_ids: [id_name_dict[genre_id] for genre_id in genre_ids])

# %%
movies.head(3)
# Out:
#    adult                     backdrop_path                         genre_ids  \
# 0  False  /r9oTasGQofvkQY5vlUXglneF64Z.jpg                  [Action, Comedy]
# 1  False  /5a4JdoFwll5DRtKMe7JLuGQ9yJm.jpg  [Drama, Science Fiction, Action]
# 2  False  /sRLC052ieEzkQs9dEtPMfFxYkej.jpg                 [Science Fiction]
#
#         id original_language  \
# 0  1029575                en
# 1   695721                en
# 2   848326                en
#
#                                       original_title  \
# 0                                    The Family Plan
# 1  The Hunger Games: The Ballad of Songbirds & Sn...
# 2             Rebel Moon - Part One: A Child of Fire
#
#                                             overview  popularity  \
# 0  Dan Morgan is many things: a devoted husband, ...    4320.505
# 1  64 years before he becomes the tyrannical pres...    2823.104
# 2  When a peaceful colony on the edge of the gala...    2761.277
#
# ...
